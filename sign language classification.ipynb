# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (16,16))
img = plt.imread('/kaggle/input/sign-language-mnist/amer_sign2.png')
plt.imshow(img)
plt.show()

# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import random
from sklearn.model_selection import train_test_split
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPool2D, Flatten, Dense, Dropout
import warnings

sns.set()
# %matplotlib inline
warnings.filterwarnings("ignore")

# %% [markdown]
# # Preparing data

# %%
df_train = pd.read_csv('../input/sign-language-mnist/sign_mnist_train/sign_mnist_train.csv')
df_train.head(-5)
# Out:
#        label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0          3     107     118     127     134     139     143     146     150
# 1          6     155     157     156     156     156     157     156     158
# 2          2     187     188     188     187     187     186     187     188
# 3          2     211     211     212     212     211     210     211     210
# 4         13     164     167     170     172     176     179     180     184
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 27445     14     167     169     170     171     171     172     172     172
# 27446     19     133     135     138     141     143     144     144     145
# 27447     11     170     172     175     177     179     182     185     186
# 27448     12     149     151     153     157     159     161     164     165
# 27449     20     162     168     172     176     179     183     184     185
#
#        pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  \
# 0         153  ...       207       207       207       207       206
# 1         158  ...        69       149       128        87        94
# 2         187  ...       202       201       200       199       198
# 3         210  ...       235       234       233       231       230
# 4         185  ...        92       105       105       108       133
# ...       ...  ...       ...       ...       ...       ...       ...
# 27445     171  ...       215       215       211       208       211
# 27446     145  ...         0         0         1         4         4
# 27447     187  ...       221       228       229       228       229
# 27448     168  ...       108       165       167       163       159
# 27449     188  ...       235       234       234       233       231
#
#        pixel780  pixel781  pixel782  pixel783  pixel784
# 0           206       206       204       203       202
# 1           163       175       103       135       149
# 2           199       198       195       194       195
# 3           226       225       222       229       163
# 4           163       157       163       164       179
# ...         ...       ...       ...       ...       ...
# 27445       201       167       119        75        48
# 27446         0         0         0         0         0
# 27447       229       227       228       227       227
# 27448       153       147       148       139       196
# 27449       229       228       228       227       226
#
# [27450 rows x 785 columns]

# %%
df_test = pd.read_csv('../input/sign-language-mnist/sign_mnist_test/sign_mnist_test.csv')
df_test.head(-5)
# Out:
#       label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0         6     149     149     150     150     150     151     151     150
# 1         5     126     128     131     132     133     134     135     135
# 2        10      85      88      92      96     105     123     135     143
# 3         0     203     205     207     206     207     209     210     209
# 4         3     188     191     193     195     199     201     202     203
# ...     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 7162     10     130     131     131     134     133     135     137     136
# 7163      4     158     161     165     169     172     175     177     179
# 7164     14     141     144     146     149     153     156     158     161
# 7165      8     158     160     160     161     161     161     164     162
# 7166     12     169     173     177     181     183     186     189     191
#
#       pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0        151  ...       138       148       127        89        82        96
# 1        136  ...        47       104       194       183       186       184
# 2        147  ...        68       166       242       227       230       227
# 3        210  ...       154       248       247       248       253       236
# 4        203  ...        26        40        64        48        29        46
# ...      ...  ...       ...       ...       ...       ...       ...       ...
# 7162     136  ...       128       106       107        63        11       147
# 7163     181  ...        78       122       141       141       141       140
# 7164     161  ...       199       203       202       201       201       201
# 7165     162  ...       177       178       176       174       173       172
# 7166     194  ...        36        27        14        35        40        15
#
#       pixel781  pixel782  pixel783  pixel784
# 0          106       112       120       107
# 1          184       184       182       180
# 2          226       225       224       222
# 3          230       240       253       255
# 4           49        46        46        53
# ...        ...       ...       ...       ...
# 7162       194       182       176       124
# 7163       141       142       143       144
# 7164       200       200       201       201
# 7165       171       169       169       167
# 7166         8        27        42        41
#
# [7167 rows x 785 columns]

# %%
plt.figure(figsize = (15,10))
sns.set_style("darkgrid")
sns.countplot(df_train['label'])
plt.show()

# %%
y_train = df_train['label']
df_train.drop(['label'], axis=1, inplace=True)
df_train.head(-5)
# Out:
#        pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  pixel9  \
# 0         107     118     127     134     139     143     146     150     153
# 1         155     157     156     156     156     157     156     158     158
# 2         187     188     188     187     187     186     187     188     187
# 3         211     211     212     212     211     210     211     210     210
# 4         164     167     170     172     176     179     180     184     185
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 27445     167     169     170     171     171     172     172     172     171
# 27446     133     135     138     141     143     144     144     145     145
# 27447     170     172     175     177     179     182     185     186     187
# 27448     149     151     153     157     159     161     164     165     168
# 27449     162     168     172     176     179     183     184     185     188
#
#        pixel10  ...  pixel775  pixel776  pixel777  pixel778  pixel779  \
# 0          156  ...       207       207       207       207       206
# 1          157  ...        69       149       128        87        94
# 2          186  ...       202       201       200       199       198
# 3          211  ...       235       234       233       231       230
# 4          186  ...        92       105       105       108       133
# ...        ...  ...       ...       ...       ...       ...       ...
# 27445      172  ...       215       215       211       208       211
# 27446      145  ...         0         0         1         4         4
# 27447      188  ...       221       228       229       228       229
# 27448      171  ...       108       165       167       163       159
# 27449      190  ...       235       234       234       233       231
#
#        pixel780  pixel781  pixel782  pixel783  pixel784
# 0           206       206       204       203       202
# 1           163       175       103       135       149
# 2           199       198       195       194       195
# 3           226       225       222       229       163
# 4           163       157       163       164       179
# ...         ...       ...       ...       ...       ...
# 27445       201       167       119        75        48
# 27446         0         0         0         0         0
# 27447       229       227       228       227       227
# 27448       153       147       148       139       196
# 27449       229       228       228       227       226
#
# [27450 rows x 784 columns]

# %%
y_test = df_test['label']
df_test.drop(['label'], axis=1, inplace=True)
df_test.head(-5)
# Out:
#       pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  pixel9  \
# 0        149     149     150     150     150     151     151     150     151
# 1        126     128     131     132     133     134     135     135     136
# 2         85      88      92      96     105     123     135     143     147
# 3        203     205     207     206     207     209     210     209     210
# 4        188     191     193     195     199     201     202     203     203
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 7162     130     131     131     134     133     135     137     136     136
# 7163     158     161     165     169     172     175     177     179     181
# 7164     141     144     146     149     153     156     158     161     161
# 7165     158     160     160     161     161     161     164     162     162
# 7166     169     173     177     181     183     186     189     191     194
#
#       pixel10  ...  pixel775  pixel776  pixel777  pixel778  pixel779  \
# 0         152  ...       138       148       127        89        82
# 1         138  ...        47       104       194       183       186
# 2         152  ...        68       166       242       227       230
# 3         209  ...       154       248       247       248       253
# 4         203  ...        26        40        64        48        29
# ...       ...  ...       ...       ...       ...       ...       ...
# 7162      137  ...       128       106       107        63        11
# 7163      184  ...        78       122       141       141       141
# 7164      161  ...       199       203       202       201       201
# 7165      161  ...       177       178       176       174       173
# 7166      195  ...        36        27        14        35        40
#
#       pixel780  pixel781  pixel782  pixel783  pixel784
# 0           96       106       112       120       107
# 1          184       184       184       182       180
# 2          227       226       225       224       222
# 3          236       230       240       253       255
# 4           46        49        46        46        53
# ...        ...       ...       ...       ...       ...
# 7162       147       194       182       176       124
# 7163       140       141       142       143       144
# 7164       201       200       200       201       201
# 7165       172       171       169       169       167
# 7166        15         8        27        42        41
#
# [7167 rows x 784 columns]

# %%
size  = 28
channels = 1
batch = 128
epochs = 100

# %%
X_train = df_train.values.reshape(df_train.shape[0], size, size, channels)
X_test = df_test.values.reshape(df_test.shape[0], size, size, channels)

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
# Out:
# X_train shape: (27455, 28, 28, 1)
# X_test shape: (7172, 28, 28, 1)

# %% [markdown]
# # Data Augmentation

# %%
datagen = ImageDataGenerator(rescale=1./255,
                             zoom_range=0.2,
                             width_shift_range=.2, height_shift_range=.2,
                             rotation_range=30,
                             brightness_range=[0.8, 1.2],
                             horizontal_flip=True)

datagenRescale = ImageDataGenerator(rescale=1./255)

X_train = datagen.flow(X_train, y_train, batch_size=batch)

X_test = datagenRescale.flow(X_test, y_test)

# %%
alphabet = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
plt.figure(figsize=(15, 15))
for i in range(9):
    plt.subplot(3, 3, i+1)
    for X_batch, Y_batch in X_train:
        image = X_batch[i]
        plt.imshow(image, cmap='gray')
        plt.xlabel(alphabet[Y_batch[i]])
        break
plt.show()

# %% [markdown]
# # Setup Callbacks

# %%
checkpoint_filepath = 'best_model.hdf5'

callback_checkpoint = ModelCheckpoint(filepath=checkpoint_filepath, save_weights_only=False, monitor='val_accuracy', mode='max', save_best_only=True)
callback_learningrate = ReduceLROnPlateau(monitor='loss', mode='min', min_delta=0.01, patience=3, factor=.75, min_lr=0.00001, verbose=1)

callbacks = [callback_checkpoint, callback_learningrate]

# %% [markdown]
# # Designing the neural network

# %%
Model = Sequential([Conv2D(filters=32,  kernel_size=(3,3), activation="relu", input_shape=(size,size,channels)),
                    MaxPool2D(2,2, padding='same'),
                    Dropout(0.2),
                 
                    Conv2D(filters=128,  kernel_size=(3,3), activation="relu"),
                    MaxPool2D(2,2, padding='same'),
                    Dropout(0.2),
                
                    Conv2D(filters=512, kernel_size=(3,3), activation="relu"),
                    MaxPool2D(2,2, padding='same'),
                    Dropout(0.2),
                    
                    
                    Flatten(),
                    
                    Dense(units=4096, activation="relu"),                 
                    Dropout(0.2),
                    
                    Dense(units=1024, activation="relu"),
                    Dropout(0.2),
                                  
                    Dense(units=256, activation="relu"),
                    Dropout(0.2),
                    
                    Dense(units=25, activation="softmax"),
])


Model.compile(optimizer='adam', loss="sparse_categorical_crossentropy", metrics=["accuracy"])


Model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 128)       36992
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 512)         590336
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              8392704
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              4195328
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               262400
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 25)                6425
# =================================================================
# Total params: 13,484,505
# Trainable params: 13,484,505
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # training

# %%
history = Model.fit(X_train, validation_data=X_test, epochs=epochs, callbacks=callbacks)
# Out:
# Epoch 1/100
# 215/215 [==============================] - 19s 67ms/step - loss: 3.1845 - accuracy: 0.0492 - val_loss: 3.0970 - val_accuracy: 0.0722
# Epoch 2/100
# 215/215 [==============================] - 14s 63ms/step - loss: 2.6852 - accuracy: 0.1457 - val_loss: 1.8647 - val_accuracy: 0.3165
# Epoch 3/100
# 215/215 [==============================] - 13s 62ms/step - loss: 1.7781 - accuracy: 0.3804 - val_loss: 1.1759 - val_accuracy: 0.5453
# Epoch 4/100
# 215/215 [==============================] - 14s 65ms/step - loss: 1.1953 - accuracy: 0.5797 - val_loss: 0.6420 - val_accuracy: 0.7638
# Epoch 5/100
# 215/215 [==============================] - 13s 62ms/step - loss: 0.8818 - accuracy: 0.6861 - val_loss: 0.5686 - val_accuracy: 0.7871
# Epoch 6/100
# 215/215 [==============================] - 14s 65ms/step - loss: 0.7207 - accuracy: 0.7513 - val_loss: 0.3823 - val_accuracy: 0.8595
# Epoch 7/100
# 215/215 [==============================] - 13s 62ms/step - loss: 0.5939 - accuracy: 0.7953 - val_loss: 0.2779 - val_accuracy: 0.9007
# Epoch 8/100
# 215/215 [==============================] - 14s 65ms/step - loss: 0.5107 - accuracy: 0.8266 - val_loss: 0.2764 - val_accuracy: 0.9007
# Epoch 9/100
# 215/215 [==============================] - 13s 62ms/step - loss: 0.4330 - accuracy: 0.8538 - val_loss: 0.2240 - val_accuracy: 0.9194
# Epoch 10/100
# 215/215 [==============================] - 14s 65ms/step - loss: 0.3981 - accuracy: 0.8660 - val_loss: 0.2467 - val_accuracy: 0.9179
# Epoch 11/100
# 215/215 [==============================] - 14s 64ms/step - loss: 0.3637 - accuracy: 0.8780 - val_loss: 0.1160 - val_accuracy: 0.9550
# Epoch 12/100
# 215/215 [==============================] - 13s 63ms/step - loss: 0.3274 - accuracy: 0.8911 - val_loss: 0.1680 - val_accuracy: 0.9361
# Epoch 13/100
# 215/215 [==============================] - 14s 65ms/step - loss: 0.3070 - accuracy: 0.8975 - val_loss: 0.1083 - val_accuracy: 0.9589
# Epoch 14/100
# 215/215 [==============================] - 14s 63ms/step - loss: 0.2844 - accuracy: 0.9082 - val_loss: 0.0935 - val_accuracy: 0.9663
# Epoch 15/100
# 215/215 [==============================] - 14s 65ms/step - loss: 0.2626 - accuracy: 0.9132 - val_loss: 0.0863 - val_accuracy: 0.9689
# Epoch 16/100
# 215/215 [==============================] - 13s 63ms/step - loss: 0.2513 - accuracy: 0.9169 - val_loss: 0.1534 - val_accuracy: 0.9407
# Epoch 17/100
# 215/215 [==============================] - 14s 65ms/step - loss: 0.2405 - accuracy: 0.9199 - val_loss: 0.0844 - val_accuracy: 0.9682
# Epoch 18/100
# 215/215 [==============================] - 13s 63ms/step - loss: 0.2343 - accuracy: 0.9238 - val_loss: 0.0793 - val_accuracy: 0.9695
# Epoch 19/100
# 215/215 [==============================] - 14s 64ms/step - loss: 0.2242 - accuracy: 0.9257 - val_loss: 0.0886 - val_accuracy: 0.9637
# Epoch 20/100
# 215/215 [==============================] - 13s 63ms/step - loss: 0.1998 - accuracy: 0.9342 - val_loss: 0.1256 - val_accuracy: 0.9544
# Epoch 21/100
# 215/215 [==============================] - 14s 63ms/step - loss: 0.2075 - accuracy: 0.9343 - val_loss: 0.0994 - val_accuracy: 0.9629
# Epoch 22/100
# 215/215 [==============================] - 14s 66ms/step - loss: 0.2019 - accuracy: 0.9341 - val_loss: 0.1207 - val_accuracy: 0.9508
# Epoch 23/100
# 215/215 [==============================] - 14s 63ms/step - loss: 0.1889 - accuracy: 0.9397 - val_loss: 0.0903 - val_accuracy: 0.9690
# Epoch 24/100
# 215/215 [==============================] - 14s 65ms/step - loss: 0.1840 - accuracy: 0.9416 - val_loss: 0.1537 - val_accuracy: 0.9451
# Epoch 25/100
# 215/215 [==============================] - 13s 63ms/step - loss: 0.1790 - accuracy: 0.9418 - val_loss: 0.1208 - val_accuracy: 0.9540
# Epoch 26/100
# 215/215 [==============================] - 14s 65ms/step - loss: 0.1738 - accuracy: 0.9420 - val_loss: 0.0672 - val_accuracy: 0.9770
# Epoch 27/100
# 215/215 [==============================] - 14s 63ms/step - loss: 0.1643 - accuracy: 0.9476 - val_loss: 0.1530 - val_accuracy: 0.9497
# Epoch 28/100
# 215/215 [==============================] - 14s 63ms/step - loss: 0.1790 - accuracy: 0.9427 - val_loss: 0.1062 - val_accuracy: 0.9596
# Epoch 29/100
# 215/215 [==============================] - 14s 65ms/step - loss: 0.1650 - accuracy: 0.9450 - val_loss: 0.0490 - val_accuracy: 0.9806
# Epoch 30/100
# 215/215 [==============================] - 14s 63ms/step - loss: 0.1666 - accuracy: 0.9471 - val_loss: 0.0661 - val_accuracy: 0.9756
# Epoch 31/100
# 215/215 [==============================] - 14s 66ms/step - loss: 0.1459 - accuracy: 0.9515 - val_loss: 0.0765 - val_accuracy: 0.9718
# Epoch 32/100
# 215/215 [==============================] - 14s 63ms/step - loss: 0.1666 - accuracy: 0.9477 - val_loss: 0.0654 - val_accuracy: 0.9721
# Epoch 33/100
# 215/215 [==============================] - 14s 65ms/step - loss: 0.1528 - accuracy: 0.9515 - val_loss: 0.0699 - val_accuracy: 0.9709
# Epoch 34/100
# 215/215 [==============================] - 14s 63ms/step - loss: 0.1546 - accuracy: 0.9528 - val_loss: 0.0409 - val_accuracy: 0.9848
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0007500000356230885.
# Epoch 35/100
# 215/215 [==============================] - 14s 65ms/step - loss: 0.1353 - accuracy: 0.9575 - val_loss: 0.0359 - val_accuracy: 0.9880
# Epoch 36/100
# 215/215 [==============================] - 14s 63ms/step - loss: 0.1204 - accuracy: 0.9595 - val_loss: 0.0240 - val_accuracy: 0.9901
# Epoch 37/100
# 215/215 [==============================] - 14s 63ms/step - loss: 0.1078 - accuracy: 0.9637 - val_loss: 0.0562 - val_accuracy: 0.9782
# Epoch 38/100
# 215/215 [==============================] - 14s 64ms/step - loss: 0.1173 - accuracy: 0.9632 - val_loss: 0.0394 - val_accuracy: 0.9858
# Epoch 39/100
# 215/215 [==============================] - 14s 63ms/step - loss: 0.1044 - accuracy: 0.9657 - val_loss: 0.0955 - val_accuracy: 0.9672
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.0005625000048894435.
# Epoch 40/100
# 215/215 [==============================] - 14s 64ms/step - loss: 0.1027 - accuracy: 0.9676 - val_loss: 0.0602 - val_accuracy: 0.9753
# Epoch 41/100
# 215/215 [==============================] - 13s 62ms/step - loss: 0.0960 - accuracy: 0.9682 - val_loss: 0.0325 - val_accuracy: 0.9870
# Epoch 42/100
# 215/215 [==============================] - 14s 65ms/step - loss: 0.0921 - accuracy: 0.9710 - val_loss: 0.0524 - val_accuracy: 0.9781
# Epoch 43/100
# 215/215 [==============================] - 13s 62ms/step - loss: 0.0970 - accuracy: 0.9695 - val_loss: 0.0251 - val_accuracy: 0.9919
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.0004218749818392098.
# Epoch 44/100
# 215/215 [==============================] - 13s 63ms/step - loss: 0.0770 - accuracy: 0.9747 - val_loss: 0.0198 - val_accuracy: 0.9939
# Epoch 45/100
# 215/215 [==============================] - 14s 66ms/step - loss: 0.0779 - accuracy: 0.9727 - val_loss: 0.0291 - val_accuracy: 0.9859
# Epoch 46/100
# 215/215 [==============================] - 14s 63ms/step - loss: 0.0771 - accuracy: 0.9752 - val_loss: 0.0288 - val_accuracy: 0.9888
# Epoch 47/100
# 215/215 [==============================] - 14s 64ms/step - loss: 0.0837 - accuracy: 0.9738 - val_loss: 0.0310 - val_accuracy: 0.9897
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.00031640623637940735.
# Epoch 48/100
# 215/215 [==============================] - 14s 63ms/step - loss: 0.0732 - accuracy: 0.9774 - val_loss: 0.0197 - val_accuracy: 0.9941
# Epoch 49/100
# 215/215 [==============================] - 14s 66ms/step - loss: 0.0630 - accuracy: 0.9791 - val_loss: 0.0245 - val_accuracy: 0.9902
# Epoch 50/100
# 215/215 [==============================] - 13s 62ms/step - loss: 0.0666 - accuracy: 0.9790 - val_loss: 0.0340 - val_accuracy: 0.9859
# Epoch 51/100
# 215/215 [==============================] - 14s 64ms/step - loss: 0.0677 - accuracy: 0.9777 - val_loss: 0.0176 - val_accuracy: 0.9925
# Epoch 52/100
# 215/215 [==============================] - 14s 63ms/step - loss: 0.0676 - accuracy: 0.9775 - val_loss: 0.0221 - val_accuracy: 0.9927
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 0.00023730468819849193.
# Epoch 53/100
# 215/215 [==============================] - 14s 63ms/step - loss: 0.0644 - accuracy: 0.9799 - val_loss: 0.0168 - val_accuracy: 0.9944
# Epoch 54/100
# 215/215 [==============================] - 14s 65ms/step - loss: 0.0608 - accuracy: 0.9803 - val_loss: 0.0154 - val_accuracy: 0.9957
# Epoch 55/100
# 215/215 [==============================] - 14s 63ms/step - loss: 0.0633 - accuracy: 0.9798 - val_loss: 0.0163 - val_accuracy: 0.9941
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 0.00017797851614886895.
# Epoch 56/100
# 215/215 [==============================] - 14s 65ms/step - loss: 0.0611 - accuracy: 0.9808 - val_loss: 0.0171 - val_accuracy: 0.9933
# Epoch 57/100
# 215/215 [==============================] - 14s 64ms/step - loss: 0.0606 - accuracy: 0.9808 - val_loss: 0.0193 - val_accuracy: 0.9918
# Epoch 58/100
# 215/215 [==============================] - 14s 65ms/step - loss: 0.0579 - accuracy: 0.9818 - val_loss: 0.0269 - val_accuracy: 0.9872
# Epoch 59/100
# 215/215 [==============================] - 14s 64ms/step - loss: 0.0523 - accuracy: 0.9832 - val_loss: 0.0152 - val_accuracy: 0.9940
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 0.0001334838816546835.
# Epoch 60/100
# 215/215 [==============================] - 14s 63ms/step - loss: 0.0516 - accuracy: 0.9843 - val_loss: 0.0183 - val_accuracy: 0.9925
# Epoch 61/100
# 215/215 [==============================] - 14s 65ms/step - loss: 0.0469 - accuracy: 0.9844 - val_loss: 0.0247 - val_accuracy: 0.9908
# Epoch 62/100
# 215/215 [==============================] - 14s 63ms/step - loss: 0.0464 - accuracy: 0.9852 - val_loss: 0.0267 - val_accuracy: 0.9894
#
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 0.00010011290578404441.
# Epoch 63/100
# 215/215 [==============================] - 14s 65ms/step - loss: 0.0542 - accuracy: 0.9826 - val_loss: 0.0187 - val_accuracy: 0.9923
# Epoch 64/100
# 215/215 [==============================] - 13s 62ms/step - loss: 0.0474 - accuracy: 0.9828 - val_loss: 0.0162 - val_accuracy: 0.9922
# Epoch 65/100
# 215/215 [==============================] - 14s 65ms/step - loss: 0.0484 - accuracy: 0.9847 - val_loss: 0.0179 - val_accuracy: 0.9918
#
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 7.508467933803331e-05.
# Epoch 66/100
# 215/215 [==============================] - 14s 64ms/step - loss: 0.0495 - accuracy: 0.9857 - val_loss: 0.0169 - val_accuracy: 0.9923
# Epoch 67/100
# 215/215 [==============================] - 14s 64ms/step - loss: 0.0429 - accuracy: 0.9863 - val_loss: 0.0154 - val_accuracy: 0.9929
# Epoch 68/100
# 215/215 [==============================] - 14s 63ms/step - loss: 0.0449 - accuracy: 0.9852 - val_loss: 0.0152 - val_accuracy: 0.9925
# Epoch 69/100
# 215/215 [==============================] - 13s 62ms/step - loss: 0.0466 - accuracy: 0.9850 - val_loss: 0.0166 - val_accuracy: 0.9929
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 5.6313510867767036e-05.
# Epoch 70/100
# 215/215 [==============================] - 14s 65ms/step - loss: 0.0476 - accuracy: 0.9849 - val_loss: 0.0112 - val_accuracy: 0.9951
# Epoch 71/100
# 215/215 [==============================] - 13s 62ms/step - loss: 0.0412 - accuracy: 0.9871 - val_loss: 0.0123 - val_accuracy: 0.9944
# Epoch 72/100
# 215/215 [==============================] - 14s 65ms/step - loss: 0.0418 - accuracy: 0.9863 - val_loss: 0.0125 - val_accuracy: 0.9948
#
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 4.223513315082528e-05.
# Epoch 73/100
# 215/215 [==============================] - 14s 63ms/step - loss: 0.0454 - accuracy: 0.9851 - val_loss: 0.0173 - val_accuracy: 0.9918
# Epoch 74/100
# 215/215 [==============================] - 14s 65ms/step - loss: 0.0405 - accuracy: 0.9865 - val_loss: 0.0156 - val_accuracy: 0.9933
# Epoch 75/100
# 215/215 [==============================] - 14s 64ms/step - loss: 0.0445 - accuracy: 0.9864 - val_loss: 0.0141 - val_accuracy: 0.9937
#
# Epoch 00075: ReduceLROnPlateau reducing learning rate to 3.167634986311896e-05.
# Epoch 76/100
# 215/215 [==============================] - 13s 63ms/step - loss: 0.0423 - accuracy: 0.9858 - val_loss: 0.0125 - val_accuracy: 0.9947
# Epoch 77/100
# 215/215 [==============================] - 14s 65ms/step - loss: 0.0439 - accuracy: 0.9867 - val_loss: 0.0155 - val_accuracy: 0.9932
# Epoch 78/100
# 215/215 [==============================] - 14s 63ms/step - loss: 0.0458 - accuracy: 0.9863 - val_loss: 0.0176 - val_accuracy: 0.9914
#
# Epoch 00078: ReduceLROnPlateau reducing learning rate to 2.3757263079460245e-05.
# Epoch 79/100
# 215/215 [==============================] - 14s 65ms/step - loss: 0.0394 - accuracy: 0.9872 - val_loss: 0.0168 - val_accuracy: 0.9918
# Epoch 80/100
# 215/215 [==============================] - 14s 64ms/step - loss: 0.0486 - accuracy: 0.9851 - val_loss: 0.0132 - val_accuracy: 0.9940
# Epoch 81/100
# 215/215 [==============================] - 14s 65ms/step - loss: 0.0439 - accuracy: 0.9867 - val_loss: 0.0148 - val_accuracy: 0.9937
#
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 1.781794799171621e-05.
# Epoch 82/100
# 215/215 [==============================] - 13s 62ms/step - loss: 0.0406 - accuracy: 0.9874 - val_loss: 0.0132 - val_accuracy: 0.9943
# Epoch 83/100
# 215/215 [==============================] - 14s 63ms/step - loss: 0.0374 - accuracy: 0.9882 - val_loss: 0.0135 - val_accuracy: 0.9946
# Epoch 84/100
# 215/215 [==============================] - 14s 64ms/step - loss: 0.0357 - accuracy: 0.9884 - val_loss: 0.0136 - val_accuracy: 0.9941
#
# Epoch 00084: ReduceLROnPlateau reducing learning rate to 1.3363460311666131e-05.
# Epoch 85/100
# 215/215 [==============================] - 13s 62ms/step - loss: 0.0412 - accuracy: 0.9862 - val_loss: 0.0140 - val_accuracy: 0.9940
# Epoch 86/100
# 215/215 [==============================] - 14s 65ms/step - loss: 0.0410 - accuracy: 0.9864 - val_loss: 0.0129 - val_accuracy: 0.9947
# Epoch 87/100
# 215/215 [==============================] - 13s 62ms/step - loss: 0.0419 - accuracy: 0.9861 - val_loss: 0.0134 - val_accuracy: 0.9940
#
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 1.0022595233749598e-05.
# Epoch 88/100
# 215/215 [==============================] - 14s 64ms/step - loss: 0.0381 - accuracy: 0.9878 - val_loss: 0.0135 - val_accuracy: 0.9941
# Epoch 89/100
# 215/215 [==============================] - 13s 63ms/step - loss: 0.0389 - accuracy: 0.9866 - val_loss: 0.0138 - val_accuracy: 0.9940
# Epoch 90/100
# 215/215 [==============================] - 14s 64ms/step - loss: 0.0382 - accuracy: 0.9871 - val_loss: 0.0140 - val_accuracy: 0.9936
#
# Epoch 00090: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 91/100
# 215/215 [==============================] - 13s 63ms/step - loss: 0.0396 - accuracy: 0.9877 - val_loss: 0.0130 - val_accuracy: 0.9944
# Epoch 92/100
# 215/215 [==============================] - 14s 63ms/step - loss: 0.0376 - accuracy: 0.9875 - val_loss: 0.0133 - val_accuracy: 0.9946
# Epoch 93/100
# 215/215 [==============================] - 14s 64ms/step - loss: 0.0422 - accuracy: 0.9856 - val_loss: 0.0148 - val_accuracy: 0.9933
# Epoch 94/100
# 215/215 [==============================] - 13s 62ms/step - loss: 0.0385 - accuracy: 0.9878 - val_loss: 0.0143 - val_accuracy: 0.9937
# Epoch 95/100
# 215/215 [==============================] - 14s 65ms/step - loss: 0.0425 - accuracy: 0.9851 - val_loss: 0.0146 - val_accuracy: 0.9936
# Epoch 96/100
# 215/215 [==============================] - 13s 62ms/step - loss: 0.0361 - accuracy: 0.9887 - val_loss: 0.0145 - val_accuracy: 0.9933
# Epoch 97/100
# 215/215 [==============================] - 14s 66ms/step - loss: 0.0367 - accuracy: 0.9872 - val_loss: 0.0138 - val_accuracy: 0.9940
# Epoch 98/100
# 215/215 [==============================] - 13s 62ms/step - loss: 0.0362 - accuracy: 0.9876 - val_loss: 0.0139 - val_accuracy: 0.9937
# Epoch 99/100
# 215/215 [==============================] - 13s 62ms/step - loss: 0.0404 - accuracy: 0.9871 - val_loss: 0.0138 - val_accuracy: 0.9934
# Epoch 100/100
# 215/215 [==============================] - 14s 64ms/step - loss: 0.0412 - accuracy: 0.9859 - val_loss: 0.0134 - val_accuracy: 0.9939

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(len(acc))

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # evaluation

# %%
score = Model.evaluate(X_test) 

print('Test loss:', score[0]) 
print('Test accuracy:', score[1])
# Out:
# 225/225 [==============================] - 1s 6ms/step - loss: 0.0134 - accuracy: 0.9939
# Test loss: 0.01339581236243248
# Test accuracy: 0.9938650131225586

# %% [markdown]
# # Confusion Matrix

# %%
df_test = pd.read_csv('../input/sign-language-mnist/sign_mnist_test/sign_mnist_test.csv')
y_test = df_test['label']
df_test.drop(['label'], axis=1, inplace=True)
X_test = df_test.values.reshape(df_test.shape[0], size, size, channels)

# %%
y_pred = np.argmax(Model.predict(X_test),axis = 1)

# %%
from sklearn.metrics import confusion_matrix
CM = confusion_matrix(y_test, y_pred)
plt.figure(figsize = (15,15))
sns.heatmap(CM, annot=True, cmap="Blues", fmt = 'g')
plt.xlabel("Predicted Classes")
plt.ylabel("True Classes")
plt.title("Confusion Matrix")
plt.show()

# %%
plt.figure(figsize=(15,15))
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(X_test[i],cmap='gray')
    plt.ylabel(f"True: {alphabet[y_test[i]]}")
    plt.xlabel(f"Predicted: {alphabet[y_pred[i]]}")
    
plt.show()
